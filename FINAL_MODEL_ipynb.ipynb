# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('true_car_listings.csv')

# %%
df.head()
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon    UT  19UDE2F32GA001284  Acura
#
#           Model
# 0    ILX6-Speed
# 1    ILX5-Speed
# 2    ILX6-Speed
# 3    ILX5-Speed
# 4  ILXAutomatic

# %%
df.tail()
# Out:
#         Price  Year  Mileage          City State                Vin   Make  \
# 852117  63215  2017        9   Culver City    CA  YV1A22MK9H1013237  Volvo
# 852118  72260  2017     3201     Englewood    NJ  YV4A22PL3H1186162  Volvo
# 852119  55999  2016    28941  Fort Collins    CO  YV4A22PL4G1000868  Volvo
# 852120  60240  2017     3005   San Leandro    CA  YV4A22NLXH1006162  Volvo
# 852121  76995  2017     2502      New York    NY  YV4BC0ZX1H1109845  Volvo
#
#           Model
# 852117    S90T6
# 852118   XC90T6
# 852119  XC90AWD
# 852120      V90
# 852121   XC90T8

# %%
df.shape
# Out:
# (16536, 8)

# %%
df.describe()
# Out:
#                Price           Year       Mileage
# count  852122.000000  852122.000000  8.521220e+05
# mean    21464.100210    2013.289145  5.250779e+04
# std     13596.202241       3.414987  4.198896e+04
# min      1500.000000    1997.000000  5.000000e+00
# 25%     13000.000000    2012.000000  2.383600e+04
# 50%     18500.000000    2014.000000  4.025600e+04
# 75%     26995.000000    2016.000000  7.218600e+04
# max    499500.000000    2018.000000  2.856196e+06

# %%
df.nunique()
# Out:
# Price       47124
# Year           22
# Mileage    158836
# City         2553
# State          59
# Vin        852075
# Make           58
# Model        2736
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Price      0
# Year       0
# Mileage    0
# City       0
# State      0
# Vin        0
# Make       0
# Model      0
# dtype: int64

# %%
df[df['Price']==df['Price'].min()]
# Out:
#         Price  Year  Mileage          City State                Vin  \
# 64010    1500  2002   107885  Philadelphia    PA  2G4WS52J321276604
# 64965    1500  1998   100296     Levittown    PA  2G4WY52M9W1574802
# 67075    1500  1998   177213  South Jordan    UT  1G4CU5219W4643710
# 68710    1500  1999   160000        Newark    NJ  2G4WB52K6X1507138
# 102581   1500  2009   129703      Lakewood    NJ  KL1TD56E69B664751
# ...       ...   ...      ...           ...   ...                ...
# 699677   1500  2004   220147     Hillsdale    MI  1G2NW52E54C120668
# 725042   1500  2001   171087        Medina    OH  1G8ZP12821Z215009
# 799006   1500  1997   274907        Newark    NJ  4T1BF22K3VU910383
# 838989   1500  2001   136301        McCook    IL  WVWPD63B61P285315
# 851197   1500  2002   181020        Newark    NJ  YV1RS61RX22195947
#
#               Make       Model
# 64010        Buick  Century4dr
# 64965        Buick  Century4dr
# 67075        Buick        Park
# 68710        Buick    Regal4dr
# 102581   Chevrolet     Aveo4dr
# ...            ...         ...
# 699677     Pontiac       Grand
# 725042      Saturn          SC
# 799006      Toyota    Camry4dr
# 838989  Volkswagen         New
# 851197       Volvo      S602.4
#
# [85 rows x 8 columns]

# %%
df[df['Mileage']==df['Mileage'].max()]
# Out:
#         Price  Year  Mileage     City State                Vin       Make  \
# 186465   4933  2002  2856196  Hayward    CA  3GNFK16T32G206964  Chevrolet
#
#               Model
# 186465  Suburban4dr

# %%
df[df['Mileage']==df['Mileage'].min()]
# Out:
#         Price  Year  Mileage          City State                Vin  \
# 696     22493  2017        5       Wichita    KS  19UDE2F32HA016028
# 5985    33399  2017        5       Wichita    KS  5J8TB3H32HL021743
# 6129    35721  2018        5     Littleton    CO  5J8TB4H37JL004139
# 6257    36000  2018        5     Littleton    CO  5J8TB4H37JL005209
# 6258    36000  2018        5     Littleton    CO  5J8TB4H34JL003045
# ...       ...   ...      ...           ...   ...                ...
# 831992  20718  2017        5     Las Vegas    NV  1VWBT7A33HC042025
# 843940  19970  2017        5       Midland    TX  3VWF17AT2HM629810
# 845291  29777  2016        5      Cerritos    CA  WVWBP7AN1GE518932
# 851563  45590  2017        5        Dallas    TX  YV440MDU5H2198321
# 851940  57247  2017        5  Falls Church    VA  YV4A22PK2H1175189
#
#               Make         Model
# 696          Acura  ILXAutomatic
# 5985         Acura        RDXFWD
# 6129         Acura        RDXAWD
# 6257         Acura        RDXAWD
# 6258         Acura        RDXAWD
# ...            ...           ...
# 831992  Volkswagen    Passat1.8T
# 843940  Volkswagen       BeetleS
# 845291  Volkswagen         CC4dr
# 851563       Volvo        XC60T5
# 851940       Volvo        XC90T6
#
# [350 rows x 8 columns]

# %%
plt.figure(figsize=(12,12))
sns.pairplot(df)

# %%
plt.figure (figsize=(15,10))
mins=df.Price.min()
maxs=df.Price.max()
scale=(maxs-mins)/20
sns.distplot(x=df['Price'])
plt.xlabel('Price',size=15, color='red')
plt.title('Price distribution',size=15,color='Orange')
plt.xticks(list(range(mins,maxs,int(scale))))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['Mileage'], df['Price'])
ax.set_xlabel('Mileage')
ax.set_ylabel('Price')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
sns.boxplot(x=df['Price'])

# %%
sns.boxplot(x=df['Mileage'])

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR =Q3-Q1
print(IQR)
# Out:
# Price      13995.0
# Year           4.0
# Mileage    48350.0
# dtype: float64

# %%
df=df[-((df<(Q1 - 1.5 * IQR))|(df > (Q3 + 1.5 *IQR))).any(axis=1)]
df.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   """Entry point for launching an IPython kernel.
# (770733, 8)

# %%
plt.figure(figsize=(10,6))
c = df.corr()
sns.heatmap(c,annot=True)
c
# Out:
#             Price      Year   Mileage
# Price    1.000000  0.433378 -0.448612
# Year     0.433378  1.000000 -0.763433
# Mileage -0.448612 -0.763433  1.000000

# %%
plt.figure(figsize=(16, 8))
sns.countplot(y=df['Year'])
plt.ylabel('Year of Manufacture',size=15)
plt.title('Yearly_Sales',size=15)
plt.show()

# %%
df.shape
# Out:
# (770733, 8)

# %%
#RANDOMFOREST

# %%
data_num = df.select_dtypes(include=[np.number])
data_cat = df.select_dtypes(include=[object])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data_cat.head()
# Out:
#                City State                Vin   Make         Model
# 0           El Paso    TX  19VDE2E53EE000083  Acura    ILX6-Speed
# 1  Long Island City    NY  19VDE1F52DE012636  Acura    ILX5-Speed
# 2           El Paso    TX  19VDE2E52DE000025  Acura    ILX6-Speed
# 3           Windsor    CO  19VDE1F71EE003817  Acura    ILX5-Speed
# 4            Lindon    UT  19UDE2F32GA001284  Acura  ILXAutomatic

# %%
encoded_cat= data_cat.apply(le.fit_transform)
encoded_cat
# Out:
#         City  State     Vin  Make  Model
# 0        646     49    3605     0    932
# 1       1259     39    3341     0    931
# 2        646     49    3603     0    932
# 3       2489      6    3458     0    931
# 4       1230     50      16     0    934
# ...      ...    ...     ...   ...    ...
# 852076  1812     35  764229    47   1917
# 852089  1396     11  762874    47   1610
# 852108  2005      5  763144    47   1916
# 852111  2005      5  763241    47   1916
# 852112  2005      5  763212    47   1916
#
# [770733 rows x 5 columns]

# %%
data = pd.concat([data_num,encoded_cat],axis=1)
data
# Out:
#         Price  Year  Mileage  City  State     Vin  Make  Model
# 0        8995  2014    35725   646     49    3605     0    932
# 1       10888  2013    19606  1259     39    3341     0    931
# 2        8995  2013    48851   646     49    3603     0    932
# 3       10999  2014    39922  2489      6    3458     0    931
# 4       14799  2016    22142  1230     50      16     0    934
# ...       ...   ...      ...   ...    ...     ...   ...    ...
# 852076  37999  2016    10801  1812     35  764229    47   1917
# 852089  44565  2016     5650  1396     11  762874    47   1610
# 852108  45280  2017        8  2005      5  763144    47   1916
# 852111  46500  2017        8  2005      5  763241    47   1916
# 852112  46530  2017       10  2005      5  763212    47   1916
#
# [770733 rows x 8 columns]

# %%
X=data.drop(['Price'],axis=1)
X.head()
# Out:
#    Year  Mileage  City  State   Vin  Make  Model
# 0  2014    35725   646     49  3605     0    932
# 1  2013    19606  1259     39  3341     0    931
# 2  2013    48851   646     49  3603     0    932
# 3  2014    39922  2489      6  3458     0    931
# 4  2016    22142  1230     50    16     0    934

# %%
y=data['Price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(X,y,train_size=0.7,random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=100, random_state=42, min_samples_split=2, min_samples_leaf=5, max_depth=30, bootstrap=True)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=30, min_samples_leaf=5, random_state=42)

# %%
y_pred=regressor.predict(X_test)

# %%
from sklearn import metrics
print('MAE:',metrics.mean_absolute_error(y_test,y_pred))
print('MSE:',metrics.mean_squared_error(y_test,y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print(f'Train Score : {regressor.score(X_train, y_train) * 100:.2f}%  and Test Score : {regressor.score(X_test, y_test) * 100:.2f}%  Random Tree Regressor.')
print("r2 score ", metrics.r2_score(y_test,y_pred))
# Out:
# MAE: 1419.3669451118521
# MSE: 4238397.364730434
# RMSE: 2058.7368371723555
# Train Score : 97.48%  and Test Score : 95.28%  Random Tree Regressor.
# r2 score  0.9528367810552041

# %%
plt.scatter(y_test, y_pred, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.show()

# %%
#Hyperparameter Tunning

# %%
rf = RandomForestRegressor(random_state=42, n_jobs=-1)
params = {
    'max_depth': [5,6,7],
    'min_samples_leaf': [3,4,5],
    'n_estimators': [10,25,30,50,100]
}

# %%
from sklearn.model_selection import GridSearchCV
# Instantiate the grid search model
grid_search = GridSearchCV(estimator=rf,
                           param_grid=params,
                           cv = 3,
                           n_jobs=-1, verbose=1)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestRegressor(n_jobs=-1, random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [5, 6, 7], 'min_samples_leaf': [3, 4, 5],
#                          'n_estimators': [10, 25, 30, 50, 100]},
#              verbose=1)

# %%
#XGBOOST

# %%
from xgboost import XGBRegressor
model = XGBRegressor()
model.fit(X_train, y_train)
# Out:
# [05:10:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(enable_categorical=False, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012, max_depth=6,
#              monotone_constraints='()', n_jobs=4, num_parallel_tree=1,
#              predictor='auto', tree_method='exact', validate_parameters=1,
#              verbosity=None)

# %%
XGB_pred=model.predict(X_test)

# %%
from sklearn import metrics
print('MAE:',metrics.mean_absolute_error(y_test,XGB_pred))
print('MSE:',metrics.mean_squared_error(y_test,XGB_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,XGB_pred)))
print(f'Train Score : {model.score(X_train, y_train) * 100:.2f}% and Test Score : {model.score(X_test, y_test) * 100:.2f}% using XGBRegressor.')
print('r2 score:',metrics.r2_score(y_test,XGB_pred))
# Out:
# MAE: 1558.4130480147328
# MSE: 4331077.1357770795
# RMSE: 2081.1240077845146
# Train Score : 95.36% and Test Score : 95.18% using XGBRegressor.
# r2 score: 0.9518054770132565
